# %%
import pandas as pd

# %% [markdown]
# # Panopto statistikk
#
# Henter ut statistikk frå Panopto og lagrer den i ei fil.

# %% [markdown]
# ## Remote Recorder
#
# Dette er automatiske opptak gjort i Haugesund; ikkje så interessant, kanskje?

# %%
remoterecorder = pd.read_csv("remoterecorderusage.csv", sep=";")
remoterecorder.head()
# Out:
#   Recorder Name Recorder Description          Recorder Version  \
# 0      Hgsd1077             Hgsd1077  Epiphan.PearlMini.4.20.0
# 1      Hgsd1077             Hgsd1077  Epiphan.PearlMini.4.20.0
# 2      Hgsd1077             Hgsd1077  Epiphan.PearlMini.4.20.0
# 3      Hgsd1077             Hgsd1077  Epiphan.PearlMini.4.20.0
# 4      Hgsd1077             Hgsd1077  Epiphan.PearlMini.4.23.1
#
#                                          Folder Name  \
# 0  2024 VÅR - BAMM1002-1 24V Maritim økonomi og l...
# 1             2024 VÅR - ING2043-1 24V Branndynamikk
# 2           2024 VÅR - MAS144 Haugesund - Maskin (3)
# 3             2024 VÅR - PSBU105 Stord/Haugesund (1)
# 4           2024 HØST - ING3059-1 24H Prosessteknikk
#
#                               Folder ID  Total Sessions Recorded  \
# 0  59cf1060-3519-42e7-82de-aff900ccea29                        1
# 1  a8819b28-755e-45cb-b0e9-b00a00a465ae                        4
# 2  4fbf6eeb-08ae-4c15-abef-b01300da6698                       16
# 3  41bd4fd5-7a8c-4efd-a665-b0ef014d9035                        1
# 4  7bf9c9ac-66fc-430d-b49a-b1ca00ba02f1                        1
#
#    Total Streams Recorded Total Hours Recorded
# 0                       2     8,13261111100515
# 1                       8     15,3303132401572
# 2                      32     59,8127616691589
# 3                       2     11,8275370364719
# 4                       2     3,83138888888889

# %% [markdown]
# Antal oppføringar i 2024:

# %%
remoterecorder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Recorder Name            66 non-null     object
#  1   Recorder Description     66 non-null     object
#  2   Recorder Version         66 non-null     object
#  3   Folder Name              66 non-null     object
#  4   Folder ID                66 non-null     object
#  5   Total Sessions Recorded  66 non-null     int64
#  6   Total Streams Recorded   66 non-null     int64
#  7   Total Hours Recorded     66 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 4.3+ KB

# %% [markdown]
# Antal opptak per opptakar

# %%
remoterecorder['Recorder Name'].value_counts()
# Out:
# Recorder Name
# hgsd2085       10
# hgsdAudE        9
# hgsdAudF        9
# hgsd2083        7
# hgsdAudG        7
# hgsdAudD        6
# Hgsd1077        5
# hgsd1091        5
# hgsdAudB        4
# hgsdaudC        2
# hgsdAudA        1
# Studio-HGSD     1
# Name: count, dtype: int64

# %% [markdown]
# ## Stream creation

# %%
streamcreation = pd.read_csv("streamcreation.csv", sep=";")
streamcreation.head(10)
# Out:
#          Stream Source Total Hours Recorded  Total Streams Recorded  \
# 0          Unspecified    0,998486295806037                       3
# 1  Panopto for Windows     196,199396218194                     806
# 2      Panopto for Mac     34,7551655552122                     200
# 3                  iOS    0,136372316678365                       5
# 4              Epiphan     598,587024439705                     257
# 5              Web API     2272,75851413039                    4707
# 6                 Zoom     1780,54465555296                    2020
# 7      Panopto Capture      146,45603782124                    1510
# 8                 RTMP     46,5888215684891                      39
#
#    Total Sessions Recorded  Oldest Created Date Most Recent Created Date  \
# 0                        3  13.05.2024 11:43:03      01.11.2024 15:37:04
# 1                      714  03.01.2024 09:45:32      27.12.2024 09:01:11
# 2                      200  17.01.2024 13:40:07      31.12.2024 16:43:01
# 3                        5  11.03.2024 12:26:19      31.10.2024 20:35:49
# 4                      255  05.01.2024 15:22:59      10.12.2024 17:00:25
# 5                     4655  02.01.2024 12:12:36      31.12.2024 08:28:19
# 6                     2020  02.01.2024 12:29:52      29.12.2024 15:09:56
# 7                     1477  03.01.2024 10:02:00      13.12.2024 11:08:27
# 8                       15  21.08.2024 14:41:58      01.11.2024 12:44:02
#
#         Deleted Hours  Deleted Streams  Deleted Sessions
# 0    0,98379870361752                2                 1
# 1    13,9903034008874              186               185
# 2    2,03237530814277               45                45
# 3  0,0679380570517646                3                 3
# 4    29,5020152748956               26                26
# 5    76,4032268020843              372               348
# 6    20,9913000011444              215               215
# 7    27,5677326117622              773               752
# 8    3,90400814745161                3                 1

# %% [markdown]
# Litt meir interessant, men eg er usikker på kva "Web API" betyr her. Kanskje support kan hjelpe? (Dette er forøvrig heile fila.)

# %% [markdown]
# ## Sessions created or edited
# Dette ser ut som veldig detaljert statistikk over antall sesjoner som er opprettet eller redigert av kvar brukar.

# %%
sessionscreated = pd.read_csv('sessionscreatedoredited.csv', sep=';', encoding='utf-8', on_bad_lines='warn')
sessionscreated.head()
# Out:
# C:\Users\AKV\AppData\Local\Temp\ipykernel_24476\2573900597.py:1: ParserWarning: Skipping line 1760: expected 27 fields, saw 28
# Skipping line 1980: expected 27 fields, saw 28
#
#   sessionscreated = pd.read_csv('sessionscreatedoredited.csv', sep=';', encoding='utf-8', on_bad_lines='warn')
#                                      Session Name  \
# 0  Møte med Zarlasht Halaimzai 2023 (copy) (copy)
# 1                         1. Intro og renessansen
# 2               Identifying Errors (Monika Bader)
# 3       Errors in Learner Language (Monika Bader)
# 4                  Kjersti Hovland's Zoom Meeting
#
#                              Session ID                  Creator  \
# 0  182e8bfa-cf05-4ca7-90b0-b1c300d643ec      unified\chop@hvl.no
# 1  acd32eea-1e76-4194-8a94-b0eb00c3a0cb      unified\suho@hvl.no
# 2  da6e5b46-454d-49c5-bbad-b0eb00b5b1f3       unified\shi@hvl.no
# 3  ba00aff7-b5bc-41de-bd9b-b0eb00b62d8d       unified\shi@hvl.no
# 4  962de148-b89b-4aab-bc0b-b0eb00bd7080  unified\kjershov@hvl.no
#
#                              Creator ID                             Email  \
# 0  cd22f17b-e73b-4573-ab93-ae1200b1aba2             christine.hope@hvl.no
# 1  6b27cfbc-2deb-4930-80a3-ae6d00b4aac7  susann.elisabeth.holmberg@hvl.no
# 2  86d9addb-df49-48f7-8e5b-af11008e3ff5         sarah.hoem.iversen@hvl.no
# 3  86d9addb-df49-48f7-8e5b-af11008e3ff5         sarah.hoem.iversen@hvl.no
# 4  0b0cce46-5a39-4cc7-9d81-af0000dbee44            kjersti.hovland@hvl.no
#
#                                          Folder Name  \
# 0  Default term - Podcast-kurs - FD-modul 20 - vå...
# 1  2024 VÅR - HI102-1 24V Historie 1500-1800. Inn...
# 2                     2024 VÅR - MGUEN201 Bergen (1)
# 3                     2024 VÅR - MGUEN201 Bergen (1)
# 4                                 Meeting Recordings
#
#                               Folder ID           Start Time Last Time Edited  \
# 0  34886c84-5be2-4498-b579-b10200c30dee  18.01.2023 12:15:37              NaN
# 1  ea636bcd-9041-45f2-ad45-b0490058caf1  02.01.2024 10:15:13              NaN
# 2  c7719157-d097-4501-ac4e-b0eb00b58481  02.01.2024 12:01:32              NaN
# 3  c7719157-d097-4501-ac4e-b0eb00b58481  02.01.2024 12:03:17              NaN
# 4  ca245d20-7aa3-49ce-91a9-af2500b5f821  02.01.2024 12:25:54              NaN
#
#   Last Approval Action  ... Average Rating Root Folder (Level 0)  \
# 0            Requested  ...            NaN                Canvas
# 1                  NaN  ...              5                Canvas
# 2                  NaN  ...            NaN                Canvas
# 3                  NaN  ...            NaN                Canvas
# 4                  NaN  ...            NaN                 Users
#
#        Subfolder (Level 1) Subfolder (Level 2)  Subfolder (Level 3)  \
# 0         Standardsemester                 NaN                  NaN
# 1  Høgskulen på Vestlandet                 HVL                  FØS
# 2  Høgskulen på Vestlandet                 HVL                 FLKI
# 3  Høgskulen på Vestlandet                 HVL                 FLKI
# 4  unified\kjershov@hvl.no                 NaN                  NaN
#
#   Subfolder (Level 4)  Subfolder (Level 5)        Subfolder (Level 6)  \
# 0                 NaN                  NaN                        NaN
# 1                 ISV       2024 VÅR (ISV)                        NaN
# 2                SLMT       MGUEN201-1 24V  2024 VÅR (MGUEN201-1 24V)
# 3                SLMT       MGUEN201-1 24V  2024 VÅR (MGUEN201-1 24V)
# 4                 NaN                  NaN                        NaN
#
#   Subfolder (Level 7) Subfolder (Level 8)
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN
#
# [5 rows x 27 columns]

# %%
sessionscreated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8051 entries, 0 to 8050
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Session Name                     8051 non-null   object
#  1   Session ID                       8051 non-null   object
#  2   Creator                          8051 non-null   object
#  3   Creator ID                       8051 non-null   object
#  4   Email                            7930 non-null   object
#  5   Folder Name                      8051 non-null   object
#  6   Folder ID                        8051 non-null   object
#  7   Start Time                       8051 non-null   object
#  8   Last Time Edited                 974 non-null    object
#  9   Last Approval Action             79 non-null     object
#  10  Last Approval Time               79 non-null     object
#  11  Last Approver Name               79 non-null     object
#  12  Last Approver Id                 79 non-null     object
#  13  Session Length (Edited minutes)  8051 non-null   object
#  14  Stream Count                     8051 non-null   int64
#  15  Stream Source                    8051 non-null   object
#  16  Rating Count                     8051 non-null   int64
#  17  Average Rating                   147 non-null    object
#  18  Root Folder (Level 0)            8048 non-null   object
#  19  Subfolder (Level 1)              6221 non-null   object
#  20  Subfolder (Level 2)              4543 non-null   object
#  21  Subfolder (Level 3)              4369 non-null   object
#  22  Subfolder (Level 4)              4188 non-null   object
#  23  Subfolder (Level 5)              4167 non-null   object
#  24  Subfolder (Level 6)              1575 non-null   object
#  25  Subfolder (Level 7)              256 non-null    object
#  26  Subfolder (Level 8)              21 non-null     object
# dtypes: int64(2), object(25)
# memory usage: 1.7+ MB

# %% [markdown]
# ## Session usage
# Dette er visst veldig detaljert statistikk over antall sesjoner for kvar film (ikkje kven som har sett, men antall sesjoner for kvar film).

# %%
sessionusage = pd.read_csv('sessionusage.csv', sep=';', encoding='utf-8', on_bad_lines='warn')
sessionusage.head()
# Out:
# C:\Users\AKV\AppData\Local\Temp\ipykernel_24476\306124198.py:1: ParserWarning: Skipping line 1046: expected 25 fields, saw 26
# Skipping line 6116: expected 25 fields, saw 26
# Skipping line 8518: expected 25 fields, saw 26
# Skipping line 10707: expected 25 fields, saw 26
#
#   sessionusage = pd.read_csv('sessionusage.csv', sep=';', encoding='utf-8', on_bad_lines='warn')
#                                         Session Name  \
# 0  Eksportere vurderinger og navneliste fra Canva...
# 1                   BYG106 VideoJBH Biaksialt moment
# 2                        Fri Sep 30 2022 10:15:57 AM
# 3  DAT108 h22 F12 - Formform validering og feilhå...
# 4   Week 6 - Wind turbine load modelling (fixed bed)
#
#                              Session ID                Creator  \
# 0  095acb40-4d77-4e02-9375-af1f00e60db3     unified\dov@hvl.no
# 1  72e07bdd-cc7f-4458-8b04-af20006cfca6     unified\jbh@hvl.no
# 2  f03173e5-3d13-432a-965b-af2000897c71  unified\davidp@hvl.no
# 3  a7d9715f-c0fe-4f06-9e3e-af20008ddb06     unified\lph@hvl.no
# 4  a788b5f1-b8bb-4878-b236-af2000ad3fa7     unified\dla@hvl.no
#
#                              Creator ID                       Email  \
# 0  a3c1bfd4-2c1b-4a9d-984d-adfe00eb5b0d     Dag.Ove.Vareberg@hvl.no
# 1  6b3e7771-2459-4fb3-9883-af0900c43671     jan.bernt.husebo@hvl.no
# 2  994196d0-ac51-451a-90b8-ad9f0067bc66     David.Parmentier@hvl.no
# 3  c13d7caf-8545-4e88-a037-ae2000907473  Lars-Petter.Helland@hvl.no
# 4  a1797e50-099c-40b5-8d2b-aefb00acad38   David.Lande-Sudall@hvl.no
#
#             Start Time                                        Folder Name  \
# 0  29.09.2022 15:57:36           Mitt Canvas for emneansvarlige-ressursen
# 1  30.09.2022 08:36:48      2022 HØST - BYG106-1 22H Betongkonstruksjoner
# 2  30.09.2022 10:20:34                    Default term - David testemne 2
# 3  30.09.2022 10:36:29  2022 HØST - DAT108-1 22H Programmering og weba...
# 4  30.09.2022 12:30:42        2022 HØST - MAS540-1 22H Fornybar havenergi
#
#                               Folder ID  Views and Downloads  Unique Viewers  \
# 0  aefcfc93-f5da-43ff-9c7b-af0100e4ab0c                    1               1
# 1  86d20113-ef83-42a0-b363-aeec00e2ea82                    7               2
# 2  b560ce21-c807-47c0-8a74-ada500684a98                    1               1
# 3  64e9d562-253b-4d5c-bf46-aeeb00c13660                   11               8
# 4  edf5acb1-7e35-4d86-83b0-aef400c09f4c                    2               1
#
#    ... Most Recent View Date Root Folder (Level 0)  \
# 0  ...   13.08.2024 09:57:02                Canvas
# 1  ...   13.10.2024 15:17:21                Canvas
# 2  ...   08.02.2024 11:23:38                Canvas
# 3  ...   23.10.2024 18:42:06                Canvas
# 4  ...   23.01.2024 09:18:48                Canvas
#
#                  Subfolder (Level 1)  Subfolder (Level 2) Subfolder (Level 3)  \
# 0  Default term - Digitalundervising                  NaN                 NaN
# 1            Høgskulen på Vestlandet                  HVL                 FIN
# 2                                NaN                  NaN                 NaN
# 3            Høgskulen på Vestlandet                  HVL                 FIN
# 4            Høgskulen på Vestlandet                  HVL                 FIN
#
#   Subfolder (Level 4) Subfolder (Level 5) Subfolder (Level 6)  \
# 0                 NaN                 NaN                 NaN
# 1                  IB      2022 HØST (IB)                 NaN
# 2                 NaN                 NaN                 NaN
# 3                IDER    2022 HØST (IDER)                 NaN
# 4                 IMM     2022 HØST (IMM)                 NaN
#
#   Subfolder (Level 7) Subfolder (Level 8)
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN
#
# [5 rows x 25 columns]

# %%
sessionusage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11656 entries, 0 to 11655
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Session Name                     11656 non-null  object
#  1   Session ID                       11656 non-null  object
#  2   Creator                          11656 non-null  object
#  3   Creator ID                       11656 non-null  object
#  4   Email                            11029 non-null  object
#  5   Start Time                       11656 non-null  object
#  6   Folder Name                      11656 non-null  object
#  7   Folder ID                        11656 non-null  object
#  8   Views and Downloads              11656 non-null  int64
#  9   Unique Viewers                   11656 non-null  int64
#  10  Minutes Delivered                11656 non-null  object
#  11  Average Minutes Delivered        11656 non-null  object
#  12  Session Length (Edited minutes)  11656 non-null  object
#  13  Rating Count                     11656 non-null  int64
#  14  Average Rating                   419 non-null    object
#  15  Most Recent View Date            11656 non-null  object
#  16  Root Folder (Level 0)            11646 non-null  object
#  17  Subfolder (Level 1)              9861 non-null   object
#  18  Subfolder (Level 2)              7694 non-null   object
#  19  Subfolder (Level 3)              7399 non-null   object
#  20  Subfolder (Level 4)              7283 non-null   object
#  21  Subfolder (Level 5)              7263 non-null   object
#  22  Subfolder (Level 6)              2961 non-null   object
#  23  Subfolder (Level 7)              397 non-null    object
#  24  Subfolder (Level 8)              51 non-null     object
# dtypes: int64(3), object(22)
# memory usage: 2.2+ MB

# %% [markdown]
# ## System views
#
# Dette er det største datasettet. Det viser i detalj kven som har sett kva film

# %%
systemviews = pd.read_csv('systemviews.csv', sep=';', encoding='utf-8', on_bad_lines='warn')
systemviews.head()
# Out:
# C:\Users\AKV\AppData\Local\Temp\ipykernel_24476\2671425890.py:1: ParserWarning: Skipping line 19478: expected 10 fields, saw 11
#
#   systemviews = pd.read_csv('systemviews.csv', sep=';', encoding='utf-8', on_bad_lines='warn')
# C:\Users\AKV\AppData\Local\Temp\ipykernel_24476\2671425890.py:1: ParserWarning: Skipping line 140115: expected 10 fields, saw 11
# Skipping line 140116: expected 10 fields, saw 11
# Skipping line 140117: expected 10 fields, saw 11
# Skipping line 140118: expected 10 fields, saw 11
# Skipping line 140119: expected 10 fields, saw 11
# Skipping line 140120: expected 10 fields, saw 11
# Skipping line 140121: expected 10 fields, saw 11
# Skipping line 140122: expected 10 fields, saw 11
# Skipping line 140123: expected 10 fields, saw 11
# Skipping line 140124: expected 10 fields, saw 11
# Skipping line 140125: expected 10 fields, saw 11
# Skipping line 140126: expected 10 fields, saw 11
# Skipping line 140127: expected 10 fields, saw 11
# Skipping line 140128: expected 10 fields, saw 11
# Skipping line 140129: expected 10 fields, saw 11
# Skipping line 140130: expected 10 fields, saw 11
# Skipping line 140131: expected 10 fields, saw 11
# Skipping line 140132: expected 10 fields, saw 11
# Skipping line 140133: expected 10 fields, saw 11
# Skipping line 140134: expected 10 fields, saw 11
# Skipping line 140135: expected 10 fields, saw 11
# Skipping line 140136: expected 10 fields, saw 11
# Skipping line 140137: expected 10 fields, saw 11
# Skipping line 140138: expected 10 fields, saw 11
# Skipping line 140139: expected 10 fields, saw 11
# Skipping line 140140: expected 10 fields, saw 11
# Skipping line 140141: expected 10 fields, saw 11
# Skipping line 140142: expected 10 fields, saw 11
# Skipping line 140143: expected 10 fields, saw 11
# Skipping line 140144: expected 10 fields, saw 11
# Skipping line 140145: expected 10 fields, saw 11
# Skipping line 140146: expected 10 fields, saw 11
# Skipping line 140147: expected 10 fields, saw 11
# Skipping line 140148: expected 10 fields, saw 11
#
#   systemviews = pd.read_csv('systemviews.csv', sep=';', encoding='utf-8', on_bad_lines='warn')
# C:\Users\AKV\AppData\Local\Temp\ipykernel_24476\2671425890.py:1: ParserWarning: Skipping line 244163: expected 10 fields, saw 11
# Skipping line 253057: expected 10 fields, saw 11
# Skipping line 253192: expected 10 fields, saw 11
# Skipping line 253500: expected 10 fields, saw 11
# Skipping line 253640: expected 10 fields, saw 11
# Skipping line 253641: expected 10 fields, saw 11
# Skipping line 253642: expected 10 fields, saw 11
#
#   systemviews = pd.read_csv('systemviews.csv', sep=';', encoding='utf-8', on_bad_lines='warn')
#              Timestamp                            Session ID  \
# 0  23.09.2024 12:40:05  fb0253e6-b1c2-4238-ae59-b1ed01119c52
# 1  23.09.2024 14:35:28  fb0253e6-b1c2-4238-ae59-b1ed01119c52
# 2  24.09.2024 10:09:10  fb0253e6-b1c2-4238-ae59-b1ed01119c52
# 3  24.09.2024 16:51:05  fb0253e6-b1c2-4238-ae59-b1ed01119c52
# 4  24.09.2024 18:58:04  53813d0f-5088-42b3-816d-b1ec013b93af
#
#                              Session Name  \
# 0                Vitskapsteori, 16.9.2024
# 1                Vitskapsteori, 16.9.2024
# 2                Vitskapsteori, 16.9.2024
# 3                Vitskapsteori, 16.9.2024
# 4  torsdag 12. september 2024 at 08:31:18
#
#                               Folder ID  \
# 0  02b263f2-1086-4ecc-a56a-b17d00d25cef
# 1  02b263f2-1086-4ecc-a56a-b17d00d25cef
# 2  02b263f2-1086-4ecc-a56a-b17d00d25cef
# 3  02b263f2-1086-4ecc-a56a-b17d00d25cef
# 4  a595c70c-a0e7-40dc-962a-b1d7013c9408
#
#                                          Folder Name              User Name  \
# 0  2024 HØST - MPUV504/MDIP504 24H Vitenskapsteor...  unified\798127@hvl.no
# 1  2024 HØST - MPUV504/MDIP504 24H Vitenskapsteor...  unified\595132@hvl.no
# 2  2024 HØST - MPUV504/MDIP504 24H Vitenskapsteor...  unified\247815@hvl.no
# 3  2024 HØST - MPUV504/MDIP504 24H Vitenskapsteor...  unified\214254@hvl.no
# 4                              unified\185963@hvl.no  unified\185963@hvl.no
#
#                                 User ID               Email Minutes Delivered  \
# 0  6dcb3a69-8259-4f6e-92a5-b06f00d254da  798127@stud.hvl.no          113,1469
# 1  4c0b838c-d022-4ce8-a8d3-af3400c7b588  595132@stud.hvl.no            0,0689
# 2  d10a1852-edc4-4046-8dd7-b1e800a92ba5  247815@stud.hvl.no           39,0835
# 3  4f65d186-0895-4ef3-9a0b-b1df00f8aac5  214254@stud.hvl.no            33,384
# 4  d5d34473-3334-4273-89f0-b1d7013bd96f  185963@stud.hvl.no            1,0535
#
#                     Viewing Type
# 0  Interactive Desktop On Demand
# 1  Interactive Desktop On Demand
# 2  Interactive Desktop On Demand
# 3  Interactive Desktop On Demand
# 4  Interactive Desktop On Demand

# %%
systemviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285343 entries, 0 to 285342
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Timestamp          285343 non-null  object
#  1   Session ID         285343 non-null  object
#  2   Session Name       285343 non-null  object
#  3   Folder ID          285343 non-null  object
#  4   Folder Name        285343 non-null  object
#  5   User Name          285343 non-null  object
#  6   User ID            285343 non-null  object
#  7   Email              254901 non-null  object
#  8   Minutes Delivered  285343 non-null  object
#  9   Viewing Type       285343 non-null  object
# dtypes: object(10)
# memory usage: 21.8+ MB

# %%
systemviews['Viewing Type'].value_counts()
# Out:
# Viewing Type
# Embedded Viewer                                     194177
# Interactive Desktop On Demand                        88919
# Downloaded Video Podcast                              1473
# Interactive Desktop Live Broadcast                     453
# Embedded video viewed through the new mobile app       172
# Embedded Live Broadcast                                100
# Streamed Video Podcast                                  23
# Downloaded Audio Podcast                                21
# Streamed Audio Podcast                                   5
# Name: count, dtype: int64
